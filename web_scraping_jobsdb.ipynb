# %% [markdown]
# # Web Scraping uisng BeautifulSoup: Scrape job advertisements in JobsDB

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os

# %%
directory='C:\\Users\\lairx78\\Desktop\\python'
os.chdir(directory)

# %% [markdown]
# Create a class to store functions that can scrape job advertisements in JobsDB by selecting occupation and number of pages

# %%
class web_scraping:

    def __init__(self, occupation, pages):
        
        self.occupation = occupation  
        self.pages = pages
        self.df_cols = ['job_title', 'company', 'job_description', 'salary', 'location', 'job_highlights', 'job_link']

    def jobsdb_link(self, job_dict):

        url_link = 'https://hk.jobsdb.com'+ job_dict['job_link']

        response_link = requests.get(url_link)
        html_link = response_link.text

        soup_link = BeautifulSoup(html_link, 'lxml')

        # find job description
        job_description = ' '.join(soup_link.find('div',{'data-automation':'jobDescription'}).find_all(string=True))
        job_description = job_description.replace('\xa0', '')
        job_description = job_description + ' '
        job_dict['job_description'] = job_description

        # find addtional information
        for i in range(len(soup_link.find('div',{'class':'z1s6m00 _5135ge0 _5135ge7'}).find_all('div', {'class':'z1s6m00 _1hbhsw6r pmwfa50 pmwfa57'}))):
            addition_info = soup_link.find('div',{'class':'z1s6m00 _5135ge0 _5135ge7'}).find_all('div', {'class':'z1s6m00 _1hbhsw6r pmwfa50 pmwfa57'})[i].find_all(string=True)
            if len(addition_info)>2:
                addition_info=[addition_info[0], ' '.join(addition_info[1:])]
            job_dict[addition_info[0]] = addition_info[1]

        return job_dict
    
    def jobsdb(self, save=False):
        
        job_ad_count=0

        df_job_ad = pd.DataFrame(columns = self.df_cols)

        for p in range(1, self.pages+1):
            
            occupation_dash = self.occupation.replace(' ', '-')
            url = 'https://hk.jobsdb.com/hk/search-jobs/' + occupation_dash + '/' + str(p)

            response = requests.get(url)
            html = response.text
            soup = BeautifulSoup(html, 'lxml')

            outer_most_point=soup.find('div',{'class':'z1s6m00', 'data-automation':'jobListing'})

            # break for loops if no jon advertisment
            if type(outer_most_point)==type(None) or outer_most_point.text=='':
                break

            for i in outer_most_point:
                
                job_dict={}
                job_ad_count+=1

                # find job title
                job_dict['job_title'] = i.find('span',{'class':'z1s6m00'}).text

                # find company
                job_dict['company'] = i.find('span', {'class': 'z1s6m00 bev08l1 _1hbhsw64y _1hbhsw60 _1hbhsw6r'}).text

                # find salary
                # neither salary nor location
                if len(i.find_all('span', {'class': 'z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ih'}))==0:
                    job_dict['salary'] = None
                # salary or location
                elif len(i.find_all('span', {'class': 'z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ih'}))==1:
                    # no location (have salary)
                    if len(i.find_all('span', {'class': 'z1s6m00 bev08l1 _1hbhsw64y _1hbhsw60 _1hbhsw6r'}))==1:
                        job_dict['salary'] = i.find_all('span', {'class': 'z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ih'})[0].text
                # salary and location
                elif len(i.find_all('span', {'class': 'z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ih'}))==2:
                    job_dict['salary'] = i.find_all('span', {'class': 'z1s6m00 _1hbhsw64y y44q7i0 y44q7i3 y44q7i21 y44q7ih'})[1].text

                # find location
                if len(i.find_all('span', {'class': 'z1s6m00 bev08l1 _1hbhsw64y _1hbhsw60 _1hbhsw6r'}))==2:
                    job_dict['location'] = i.find_all('span', {'class': 'z1s6m00 bev08l1 _1hbhsw64y _1hbhsw60 _1hbhsw6r'})[1].text

                # find job highlights
                highlights_len = len(i.find_all('span', {'class': 'z1s6m00 _1hbhsw64y y44q7i0 y44q7i1 y44q7i21 _1d0g9qk4 y44q7i7'}))
                if highlights_len > 0:
                    job_highlights=''
                    for k in range(highlights_len):
                        if k==highlights_len-1:
                            job_highlights = job_highlights + ' ' + i.find_all('span', {'class': 'z1s6m00 _1hbhsw64y y44q7i0 y44q7i1 y44q7i21 _1d0g9qk4 y44q7i7'})[k].text
                        else:
                            job_highlights = job_highlights + ' ' + i.find_all('span', {'class': 'z1s6m00 _1hbhsw64y y44q7i0 y44q7i1 y44q7i21 _1d0g9qk4 y44q7i7'})[k].text + ','
                    job_dict['job_highlights']=job_highlights

                # find job_link
                if len(i.find_all('div',{'class':'z1s6m00 _1hbhsw6ce'}))==2:
                    div_link=i.find_all('div',{'class':'z1s6m00 _1hbhsw6ce'})[1]
                else:
                    div_link=i.find_all('div',{'class':'z1s6m00 _1hbhsw6ce'})[0]
                job_dict['job_link'] = div_link.find('a').attrs['href']

                for key in self.df_cols:
                    if key not in list(job_dict.keys()):
                        job_dict[key] = None

                # find job description and additional info
                job_dict = self.jobsdb_link(job_dict)

                #dave to dataframe
                for col in job_dict.keys():
                    if col not in df_job_ad.columns:
                        df_job_ad[col] = None

                for key in df_job_ad.columns:
                    if key not in list(job_dict.keys()):
                        job_dict[key] = None

                df_job_ad = pd.concat([df_job_ad, pd.Series(job_dict).to_frame().T], ignore_index=True)

        print('Number of job advertisement: ', job_ad_count)
    
        if save==True:
            df_job_ad.to_csv('jobsdb_' + self.occupation + '.csv', index=False)
       
        return df_job_ad

# %% [markdown]
# Run the function in the class to do the scraping by input two attributes for __init__ function
#
# There are two attributes:
# 1. occupation: choosing which type of occupation you wanted to scrape
# 2. pages: choosing the number of pages you wanted to scrape (each pages contain 30 job advertisements)

# %%
# scrape 1 page which is 30 job posts for data analyst

web_scraping('data analyst',1).jobsdb(save=True)
# Out:
# Number of job advertisement:  30
#                                             job_title  \
# 0   Senior Data Analyst (Business Planning & Analy...
# 1       Business Analyst / Assistant Business Analyst
# 2   (Senior) Data Scientist / Engineer - Operation...
# 3                             (Senior) Data Scientist
# 4                    Analyst - 2023 Graduate Position
# 5                                    Business Analyst
# 6                                      System Analyst
# 7                           Digital Analyst (Ref: MG)
# 8               Business Analyst (Financial Services)
# 9                                System Analyst (F&B)
# 10       Postdoctoral Researcher, AI and Data Science
# 11   Business Analyst x 1 (Working Location: Whampoa)
# 12                              Business Data Analyst
# 13                                       Data Analyst
# 14                                       Data Analyst
# 15            Business Analyst (Sports & Hospitality)
# 16                             Data Analyst (Product)
# 17                          Data Analyst - ESF Centre
# 18                            Business Analyst (Data)
# 19                         Data Analyst (Reinsurance)
# 20                                       Data Analyst
# 21            Data Analyst (Banking, Tableau, Python)
# 22                     Data Analyst (Data Management)
# 23                             Data Analyst (Quality)
# 24                                    AI Data Analyst
# 25                                 Operations Analyst
# 26   Contract Junior Data Analyst  (Subject to renew)
# 27                              Customer Data Analyst
# 28           IT Data Analyst / Database Administrator
# 29                      SQL Data Analytics Consultant
#
#                                               company  \
# 0    Hutchison Telecommunications (Hong Kong) Limited
# 1                       BridgeBuilder Company Limited
# 2     TCL Corporate Research (Hong Kong) Co., Limited
# 3   Hong Kong Industrial Artificial Intelligence a...
# 4                   AVISTA Valuation Advisory Limited
# 5                       Citistore (Hong Kong) Limited
# 6                    Panasonic Hong Kong Co., Limited
# 7    Hutchison Telecommunications (Hong Kong) Limited
# 8                                              Hudson
# 9                             Kabushikigaisha Limited
# 10  Hong Kong Industrial Artificial Intelligence a...
# 11                                   Varmeego Limited
# 12                               Hong Kong Go Limited
# 13                      Route 3 (CPS) Company Limited
# 14                  Lockton Companies (Hong Kong) Ltd
# 15                             ConnectedGroup Limited
# 16                        GoAnimate Hong Kong Limited
# 17                     The English Schools Foundation
# 18                                       Michael Page
# 19                                      AXA Hong Kong
# 20  Laboratory for AI-Powered Financial Technologi...
# 21                      PERSOLKELLY Hong Kong Limited
# 22            Wheelock Properties (Hong Kong) Limited
# 23                        GoAnimate Hong Kong Limited
# 24                     Aztech Systems (Hong Kong) Ltd
# 25                  Asia Airfreight Terminal Co. Ltd.
# 26                           Peoplebank Hong Kong Ltd
# 27   Century Distribution Systems (Hong Kong) Limited
# 28                  Conpak Management Consultants Ltd
# 29                                  NCSI (HK) Limited
#
#                                       job_description  \
# 0   Responsibilities: Perform various design, deve...
# 1   To  cope with the rapid growth, we are looking...
# 2   Job Description This role would participate in...
# 3   Hong Kong Industrial Artificial Intelligence a...
# 4   Service: Business Valuation Location: Hong Kon...
# 5   KEY RESPONSIBILITIES: Act as a bridge between ...
# 6   What you’ll be doing? Manage and participate i...
# 7   Responsibilities: Take charge of digital data ...
# 8   Working as a Business Analyst/ Senior business...
# 9   Responsibilities: Implements computer system r...
# 10  Hong Kong Industrial Artificial Intelligence a...
# 11  Responsibilities Collect and analyze user requ...
# 12  Job Description: Responsible for data extracti...
# 13     Carry out data analytics and business analy...
# 14  As part of the Risk Solutions team, the role o...
# 15  This world leading organization is consistentl...
# 16  VYOND – Data Analyst (Product) AtVYOND, our mi...
# 17  We are looking for a data analyst to join our ...
# 18  Large-scale properties group Data-driven proje...
# 19  Responsibilities: Manage the accuracy and effi...
# 20  The Laboratory for AI-Powered Financial Techno...
# 21  Our client is a leading financial services gro...
# 22  Responsibilities: Collaborate with internal st...
# 23  Data Analyst AtVyond, our mission is to put th...
# 24  Responsibilities Work closely with AI Engineer...
# 25  Duties Prepare and coordinate new system devel...
# 26  Job duties: Identify, measure, review and reva...
# 27  In recent years, Century has significantly inv...
# 28  Responsibilities: Collaborate with stakeholder...
# 29  This position has responsibility for the Data ...
#
#                      salary        location  \
# 0                      None        Tsing Yi
# 1                      None       Kwai Hing
# 2                      None     Shatin Area
# 3                      None     Tai Po Area
# 4                      None        Wan Chai
# 5                      None  Tsuen Wan Area
# 6                      None        Mong Kok
# 7                      None        Tsing Yi
# 8                      None            None
# 9                      None     Kowloon Bay
# 10                     None     Shatin Area
# 11                     None            None
# 12                     None    Causeway Bay
# 13                     None        Wan Chai
# 14                     None      Quarry Bay
# 15                     None            None
# 16                     None      Sheung Wan
# 17                     None            None
# 18  HK$35K - 44,999 /month             None
# 19                     None            None
# 20                     None     Shatin Area
# 21                     None       Kwun Tong
# 22                     None   Southern Area
# 23                     None      Sheung Wan
# 24                     None     Shatin Area
# 25                     None    Airport Area
# 26                     None       Kwun Tong
# 27                     None       Kwun Tong
# 28                     None   Tsim Sha Tsui
# 29                     None       Kwun Tong
#
#                                        job_highlights  \
# 0    Knowledge with programming / data analysis, D...
# 1    Project Implementation, Good analytical-mind,...
# 2    Perform mathematical modeling, Master Product...
# 3    Contribute whole life cycle of product develo...
# 4    Valuations for financial reporting and transa...
# 5    Manage and monitor various IT projects, Min. ...
# 6    Stable MNC in-house exposure with flex work h...
# 7    Degree, 4+ yrs e-Commerce & digital marketing...
# 8    Business Analyst, Project Manager, Transforma...
# 9    MS SQL database, VB.net and Python, Business ...
# 10   5-day work week, Medical & dental benefits, C...
# 11   Collect and analyze user requirement, Initiat...
# 12   Data Analysis for a growing e-commerce platfo...
# 13   Carry out data analytics and business analysi...
# 14   Fresh graduates are also welcome, Part time, ...
# 15   Business Analyst, Targeted Segment, Stable wo...
# 16   2+yrs exp in software development, data analy...
# 17   Working knowledge of Python, Experience in da...
# 18   Large-scale properties group in Hong Kong, Da...
# 19   Experience in data analytics field is preferr...
# 20   18 days Annual Leave, Medical Insurance, Expe...
# 21   1 year experience in building reports, Hands ...
# 22   Provide a spectrum of data services, Strong k...
# 23   2+ years of experience in data analysis, SQL ...
# 24                                               None
# 25   13 days annual leave, 5-day week, double pay,...
# 26   5 days Work, Less experienced candidates are ...
# 27   Excel, Word, Visio, sql, computer, science,, ...
# 28   Offer professional training, Data centric tra...
# 29   Leading Data Analytics Solutions Company, Man...
#
#                                              job_link Career Level  \
# 0   /hk/en/job/senior-data-analyst-business-planni...  Entry Level
# 1   /hk/en/job/business-analyst-assistant-business...       Middle
# 2   /hk/en/job/senior-data-scientist-engineer-oper...       Middle
# 3   /hk/en/job/senior-data-scientist-1000030106150...       Middle
# 4   /hk/en/job/analyst-2023-graduate-position-1000...  Entry Level
# 5   /hk/en/job/business-analyst-100003010610793?to...       Middle
# 6   /hk/en/job/system-analyst-100003010617784?toke...       Middle
# 7   /hk/en/job/digital-analyst-ref%3A-mg-100003010...       Middle
# 8   /hk/en/job/business-analyst-financial-services...  Entry Level
# 9   /hk/en/job/system-analyst-f-b-100003010607521?...  Entry Level
# 10  /hk/en/job/postdoctoral-researcher-ai-and-data...  Entry Level
# 11  /hk/en/job/business-analyst-x-1-working-locati...       Middle
# 12  /hk/en/job/business-data-analyst-1000030106189...  Entry Level
# 13  /hk/en/job/data-analyst-100003010615922?token=...  Entry Level
# 14  /hk/en/job/data-analyst-100003010615131?token=...  Entry Level
# 15  /hk/en/job/business-analyst-sports-hospitality...       Middle
# 16  /hk/en/job/data-analyst-product-10000301061727...         None
# 17  /hk/en/job/data-analyst-esf-centre-10000301061...  Entry Level
# 18  /hk/en/job/business-analyst-data-1000030106185...       Middle
# 19  /hk/en/job/data-analyst-reinsurance-1000030106...  Entry Level
# 20  /hk/en/job/data-analyst-100003010617709?token=...         None
# 21  /hk/en/job/data-analyst-banking-tableau-python...  Entry Level
# 22  /hk/en/job/data-analyst-data-management-100003...  Entry Level
# 23  /hk/en/job/data-analyst-quality-10000301061727...         None
# 24  /hk/en/job/ai-data-analyst-100003010613348?tok...  Entry Level
# 25  /hk/en/job/operations-analyst-100003010619026?...       Middle
# 26  /hk/en/job/contract-junior-data-analyst-subjec...  Entry Level
# 27  /hk/en/job/customer-data-analyst-1000030106122...  Entry Level
# 28  /hk/en/job/it-data-analyst-database-administra...         None
# 29  /hk/en/job/sql-data-analytics-consultant-10000...       Middle
#
#           Qualification Years of Experience              Job Type  \
# 0   Non-Degree Tertiary             3 years  Full Time, Permanent
# 1   Non-Degree Tertiary                 N/A  Full Time, Permanent
# 2                  None                None             Full Time
# 3          Postgraduate             7 years  Full Time, Permanent
# 4                Degree                 N/A  Full Time, Permanent
# 5                Degree             5 years  Full Time, Permanent
# 6   Non-Degree Tertiary             3 years  Full Time, Permanent
# 7                Degree             5 years  Full Time, Permanent
# 8                Degree                 N/A  Full Time, Permanent
# 9   Non-Degree Tertiary             4 years             Full Time
# 10         Postgraduate                None  Full Time, Permanent
# 11               Degree             3 years             Full Time
# 12                 None                None  Full Time, Permanent
# 13               Degree              1 year  Full Time, Permanent
# 14               Degree             2 years  Full Time, Permanent
# 15               Degree                 N/A  Full Time, Permanent
# 16                 None                None             Permanent
# 17               Degree                None             Full Time
# 18               Degree                 N/A  Full Time, Permanent
# 19               Degree             3 years  Full Time, Permanent
# 20               Degree                None             Full Time
# 21               Degree              1 year             Full Time
# 22               Degree             4 years  Full Time, Permanent
# 23                 None                None             Permanent
# 24               Degree             2 years             Full Time
# 25               Degree             3 years  Full Time, Permanent
# 26               Degree                 N/A   Full Time, Contract
# 27               Degree                None  Full Time, Permanent
# 28                 None                None  Full Time, Permanent
# 29               Degree              1 year  Full Time, Permanent
#
#                                         Job Functions  \
# 0   Information Technology (IT) ,  DBA ,  Product ...
# 1   Information Technology (IT) ,  Application Spe...
# 2   Engineering ,  Electrical / Electronics ,  Inf...
# 3   Sales, CS & Business Devpt ,  Business Develop...
# 4   Accounting ,  Financial Analyst ,  Banking / F...
# 5   Information Technology (IT) ,  IT Management ,...
# 6    Information Technology (IT) ,  Support ,  Others
# 7   Marketing / Public Relations ,  Digital Market...
# 8   Information Technology (IT) ,  Product Managem...
# 9   Information Technology (IT) ,  Testing / QA , ...
# 10  Engineering ,  Electrical / Electronics ,  Sci...
# 11  Information Technology (IT) ,  Product Managem...
# 12  Information Technology (IT) ,  Product Managem...
# 13               Transportation & Logistics ,  Others
# 14  Banking / Finance ,  Analyst ,  Professional S...
# 15  Professional Services ,  Business Analysis / D...
# 16  Information Technology (IT) ,  Others ,  Data ...
# 17  Information Technology (IT) ,  Application Spe...
# 18  Professional Services ,  Business Analysis / D...
# 19  Banking / Finance ,  Others ,  Professional Se...
# 20  Banking / Finance ,  Analyst ,  Information Te...
# 21  Professional Services ,  Business Analysis / D...
# 22  Information Technology (IT) ,  DBA ,  Others ,...
# 23  Information Technology (IT) ,  Others ,  Data ...
# 24                              Engineering ,  Others
# 25  Transportation & Logistics ,  Others ,  Profes...
# 26  Information Technology (IT) ,  Support ,  Test...
# 27  Professional Services ,  Business Analysis / D...
# 28  Information Technology (IT) ,  Application Spe...
# 29  Information Technology (IT) ,  Product Managem...
#
#                                 Company Website
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                         http://www.avaval.com
# 5                                          None
# 6   http://www.panasonic.com/about/overview.asp
# 7                                          None
# 8                         https://www.hudson.hk
# 9                                          None
# 10                                         None
# 11                                         None
# 12                                         None
# 13                                         None
# 14                http://www.global.lockton.com
# 15                http://www.connectedgroup.com
# 16                       https://www.vyond.com/
# 17                        http://www.esf.edu.hk
# 18                http://www.michaelpage.com.hk
# 19                       https://www.axa.com.hk
# 20                                         None
# 21                http://www.persolkelly.com.hk
# 22                                         None
# 23                       https://www.vyond.com/
# 24                     http://www.aztech.com.sg
# 25                        http://www.aat.com.hk
# 26                 http://www.peoplebank.com.hk
# 27                     http://www.centurysc.com
# 28                       http://www.conpak.com/
# 29                         http://www.ncs-i.com

# %% [markdown]
# After scraping, the function will export a csv file to store all the job advertisements, read it as a dataframe

# %%
df_data_analyst = pd.read_csv('jobsdb_data analyst.csv', header=0)

df_data_analyst
# Out:
#                                             job_title  \
# 0   Senior Data Analyst (Business Planning & Analy...
# 1       Business Analyst / Assistant Business Analyst
# 2   (Senior) Data Scientist / Engineer - Operation...
# 3                             (Senior) Data Scientist
# 4                    Analyst - 2023 Graduate Position
# 5                                    Business Analyst
# 6                                      System Analyst
# 7                           Digital Analyst (Ref: MG)
# 8               Business Analyst (Financial Services)
# 9                                System Analyst (F&B)
# 10       Postdoctoral Researcher, AI and Data Science
# 11   Business Analyst x 1 (Working Location: Whampoa)
# 12                              Business Data Analyst
# 13                                       Data Analyst
# 14                                       Data Analyst
# 15            Business Analyst (Sports & Hospitality)
# 16                             Data Analyst (Product)
# 17                          Data Analyst - ESF Centre
# 18                            Business Analyst (Data)
# 19                         Data Analyst (Reinsurance)
# 20                                       Data Analyst
# 21            Data Analyst (Banking, Tableau, Python)
# 22                     Data Analyst (Data Management)
# 23                             Data Analyst (Quality)
# 24                                    AI Data Analyst
# 25                                 Operations Analyst
# 26   Contract Junior Data Analyst  (Subject to renew)
# 27                              Customer Data Analyst
# 28           IT Data Analyst / Database Administrator
# 29                      SQL Data Analytics Consultant
#
#                                               company  \
# 0    Hutchison Telecommunications (Hong Kong) Limited
# 1                       BridgeBuilder Company Limited
# 2     TCL Corporate Research (Hong Kong) Co., Limited
# 3   Hong Kong Industrial Artificial Intelligence a...
# 4                   AVISTA Valuation Advisory Limited
# 5                       Citistore (Hong Kong) Limited
# 6                    Panasonic Hong Kong Co., Limited
# 7    Hutchison Telecommunications (Hong Kong) Limited
# 8                                              Hudson
# 9                             Kabushikigaisha Limited
# 10  Hong Kong Industrial Artificial Intelligence a...
# 11                                   Varmeego Limited
# 12                               Hong Kong Go Limited
# 13                      Route 3 (CPS) Company Limited
# 14                  Lockton Companies (Hong Kong) Ltd
# 15                             ConnectedGroup Limited
# 16                        GoAnimate Hong Kong Limited
# 17                     The English Schools Foundation
# 18                                       Michael Page
# 19                                      AXA Hong Kong
# 20  Laboratory for AI-Powered Financial Technologi...
# 21                      PERSOLKELLY Hong Kong Limited
# 22            Wheelock Properties (Hong Kong) Limited
# 23                        GoAnimate Hong Kong Limited
# 24                     Aztech Systems (Hong Kong) Ltd
# 25                  Asia Airfreight Terminal Co. Ltd.
# 26                           Peoplebank Hong Kong Ltd
# 27   Century Distribution Systems (Hong Kong) Limited
# 28                  Conpak Management Consultants Ltd
# 29                                  NCSI (HK) Limited
#
#                                       job_description  \
# 0   Responsibilities: Perform various design, deve...
# 1   To  cope with the rapid growth, we are looking...
# 2   Job Description This role would participate in...
# 3   Hong Kong Industrial Artificial Intelligence a...
# 4   Service: Business Valuation Location: Hong Kon...
# 5   KEY RESPONSIBILITIES: Act as a bridge between ...
# 6   What you’ll be doing? Manage and participate i...
# 7   Responsibilities: Take charge of digital data ...
# 8   Working as a Business Analyst/ Senior business...
# 9   Responsibilities: Implements computer system r...
# 10  Hong Kong Industrial Artificial Intelligence a...
# 11  Responsibilities Collect and analyze user requ...
# 12  Job Description: Responsible for data extracti...
# 13     Carry out data analytics and business analy...
# 14  As part of the Risk Solutions team, the role o...
# 15  This world leading organization is consistentl...
# 16  VYOND – Data Analyst (Product) AtVYOND, our mi...
# 17  We are looking for a data analyst to join our ...
# 18  Large-scale properties group Data-driven proje...
# 19  Responsibilities: Manage the accuracy and effi...
# 20  The Laboratory for AI-Powered Financial Techno...
# 21  Our client is a leading financial services gro...
# 22  Responsibilities: Collaborate with internal st...
# 23  Data Analyst AtVyond, our mission is to put th...
# 24  Responsibilities Work closely with AI Engineer...
# 25  Duties Prepare and coordinate new system devel...
# 26  Job duties: Identify, measure, review and reva...
# 27  In recent years, Century has significantly inv...
# 28  Responsibilities: Collaborate with stakeholder...
# 29  This position has responsibility for the Data ...
#
#                      salary        location  \
# 0                       NaN        Tsing Yi
# 1                       NaN       Kwai Hing
# 2                       NaN     Shatin Area
# 3                       NaN     Tai Po Area
# 4                       NaN        Wan Chai
# 5                       NaN  Tsuen Wan Area
# 6                       NaN        Mong Kok
# 7                       NaN        Tsing Yi
# 8                       NaN             NaN
# 9                       NaN     Kowloon Bay
# 10                      NaN     Shatin Area
# 11                      NaN             NaN
# 12                      NaN    Causeway Bay
# 13                      NaN        Wan Chai
# 14                      NaN      Quarry Bay
# 15                      NaN             NaN
# 16                      NaN      Sheung Wan
# 17                      NaN             NaN
# 18  HK$35K - 44,999 /month              NaN
# 19                      NaN             NaN
# 20                      NaN     Shatin Area
# 21                      NaN       Kwun Tong
# 22                      NaN   Southern Area
# 23                      NaN      Sheung Wan
# 24                      NaN     Shatin Area
# 25                      NaN    Airport Area
# 26                      NaN       Kwun Tong
# 27                      NaN       Kwun Tong
# 28                      NaN   Tsim Sha Tsui
# 29                      NaN       Kwun Tong
#
#                                        job_highlights  \
# 0    Knowledge with programming / data analysis, D...
# 1    Project Implementation, Good analytical-mind,...
# 2    Perform mathematical modeling, Master Product...
# 3    Contribute whole life cycle of product develo...
# 4    Valuations for financial reporting and transa...
# 5    Manage and monitor various IT projects, Min. ...
# 6    Stable MNC in-house exposure with flex work h...
# 7    Degree, 4+ yrs e-Commerce & digital marketing...
# 8    Business Analyst, Project Manager, Transforma...
# 9    MS SQL database, VB.net and Python, Business ...
# 10   5-day work week, Medical & dental benefits, C...
# 11   Collect and analyze user requirement, Initiat...
# 12   Data Analysis for a growing e-commerce platfo...
# 13   Carry out data analytics and business analysi...
# 14   Fresh graduates are also welcome, Part time, ...
# 15   Business Analyst, Targeted Segment, Stable wo...
# 16   2+yrs exp in software development, data analy...
# 17   Working knowledge of Python, Experience in da...
# 18   Large-scale properties group in Hong Kong, Da...
# 19   Experience in data analytics field is preferr...
# 20   18 days Annual Leave, Medical Insurance, Expe...
# 21   1 year experience in building reports, Hands ...
# 22   Provide a spectrum of data services, Strong k...
# 23   2+ years of experience in data analysis, SQL ...
# 24                                                NaN
# 25   13 days annual leave, 5-day week, double pay,...
# 26   5 days Work, Less experienced candidates are ...
# 27   Excel, Word, Visio, sql, computer, science,, ...
# 28   Offer professional training, Data centric tra...
# 29   Leading Data Analytics Solutions Company, Man...
#
#                                              job_link Career Level  \
# 0   /hk/en/job/senior-data-analyst-business-planni...  Entry Level
# 1   /hk/en/job/business-analyst-assistant-business...       Middle
# 2   /hk/en/job/senior-data-scientist-engineer-oper...       Middle
# 3   /hk/en/job/senior-data-scientist-1000030106150...       Middle
# 4   /hk/en/job/analyst-2023-graduate-position-1000...  Entry Level
# 5   /hk/en/job/business-analyst-100003010610793?to...       Middle
# 6   /hk/en/job/system-analyst-100003010617784?toke...       Middle
# 7   /hk/en/job/digital-analyst-ref%3A-mg-100003010...       Middle
# 8   /hk/en/job/business-analyst-financial-services...  Entry Level
# 9   /hk/en/job/system-analyst-f-b-100003010607521?...  Entry Level
# 10  /hk/en/job/postdoctoral-researcher-ai-and-data...  Entry Level
# 11  /hk/en/job/business-analyst-x-1-working-locati...       Middle
# 12  /hk/en/job/business-data-analyst-1000030106189...  Entry Level
# 13  /hk/en/job/data-analyst-100003010615922?token=...  Entry Level
# 14  /hk/en/job/data-analyst-100003010615131?token=...  Entry Level
# 15  /hk/en/job/business-analyst-sports-hospitality...       Middle
# 16  /hk/en/job/data-analyst-product-10000301061727...          NaN
# 17  /hk/en/job/data-analyst-esf-centre-10000301061...  Entry Level
# 18  /hk/en/job/business-analyst-data-1000030106185...       Middle
# 19  /hk/en/job/data-analyst-reinsurance-1000030106...  Entry Level
# 20  /hk/en/job/data-analyst-100003010617709?token=...          NaN
# 21  /hk/en/job/data-analyst-banking-tableau-python...  Entry Level
# 22  /hk/en/job/data-analyst-data-management-100003...  Entry Level
# 23  /hk/en/job/data-analyst-quality-10000301061727...          NaN
# 24  /hk/en/job/ai-data-analyst-100003010613348?tok...  Entry Level
# 25  /hk/en/job/operations-analyst-100003010619026?...       Middle
# 26  /hk/en/job/contract-junior-data-analyst-subjec...  Entry Level
# 27  /hk/en/job/customer-data-analyst-1000030106122...  Entry Level
# 28  /hk/en/job/it-data-analyst-database-administra...          NaN
# 29  /hk/en/job/sql-data-analytics-consultant-10000...       Middle
#
#           Qualification Years of Experience              Job Type  \
# 0   Non-Degree Tertiary             3 years  Full Time, Permanent
# 1   Non-Degree Tertiary                 NaN  Full Time, Permanent
# 2                   NaN                 NaN             Full Time
# 3          Postgraduate             7 years  Full Time, Permanent
# 4                Degree                 NaN  Full Time, Permanent
# 5                Degree             5 years  Full Time, Permanent
# 6   Non-Degree Tertiary             3 years  Full Time, Permanent
# 7                Degree             5 years  Full Time, Permanent
# 8                Degree                 NaN  Full Time, Permanent
# 9   Non-Degree Tertiary             4 years             Full Time
# 10         Postgraduate                 NaN  Full Time, Permanent
# 11               Degree             3 years             Full Time
# 12                  NaN                 NaN  Full Time, Permanent
# 13               Degree              1 year  Full Time, Permanent
# 14               Degree             2 years  Full Time, Permanent
# 15               Degree                 NaN  Full Time, Permanent
# 16                  NaN                 NaN             Permanent
# 17               Degree                 NaN             Full Time
# 18               Degree                 NaN  Full Time, Permanent
# 19               Degree             3 years  Full Time, Permanent
# 20               Degree                 NaN             Full Time
# 21               Degree              1 year             Full Time
# 22               Degree             4 years  Full Time, Permanent
# 23                  NaN                 NaN             Permanent
# 24               Degree             2 years             Full Time
# 25               Degree             3 years  Full Time, Permanent
# 26               Degree                 NaN   Full Time, Contract
# 27               Degree                 NaN  Full Time, Permanent
# 28                  NaN                 NaN  Full Time, Permanent
# 29               Degree              1 year  Full Time, Permanent
#
#                                         Job Functions  \
# 0   Information Technology (IT) ,  DBA ,  Product ...
# 1   Information Technology (IT) ,  Application Spe...
# 2   Engineering ,  Electrical / Electronics ,  Inf...
# 3   Sales, CS & Business Devpt ,  Business Develop...
# 4   Accounting ,  Financial Analyst ,  Banking / F...
# 5   Information Technology (IT) ,  IT Management ,...
# 6    Information Technology (IT) ,  Support ,  Others
# 7   Marketing / Public Relations ,  Digital Market...
# 8   Information Technology (IT) ,  Product Managem...
# 9   Information Technology (IT) ,  Testing / QA , ...
# 10  Engineering ,  Electrical / Electronics ,  Sci...
# 11  Information Technology (IT) ,  Product Managem...
# 12  Information Technology (IT) ,  Product Managem...
# 13               Transportation & Logistics ,  Others
# 14  Banking / Finance ,  Analyst ,  Professional S...
# 15  Professional Services ,  Business Analysis / D...
# 16  Information Technology (IT) ,  Others ,  Data ...
# 17  Information Technology (IT) ,  Application Spe...
# 18  Professional Services ,  Business Analysis / D...
# 19  Banking / Finance ,  Others ,  Professional Se...
# 20  Banking / Finance ,  Analyst ,  Information Te...
# 21  Professional Services ,  Business Analysis / D...
# 22  Information Technology (IT) ,  DBA ,  Others ,...
# 23  Information Technology (IT) ,  Others ,  Data ...
# 24                              Engineering ,  Others
# 25  Transportation & Logistics ,  Others ,  Profes...
# 26  Information Technology (IT) ,  Support ,  Test...
# 27  Professional Services ,  Business Analysis / D...
# 28  Information Technology (IT) ,  Application Spe...
# 29  Information Technology (IT) ,  Product Managem...
#
#                                 Company Website
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                         http://www.avaval.com
# 5                                           NaN
# 6   http://www.panasonic.com/about/overview.asp
# 7                                           NaN
# 8                         https://www.hudson.hk
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                http://www.global.lockton.com
# 15                http://www.connectedgroup.com
# 16                       https://www.vyond.com/
# 17                        http://www.esf.edu.hk
# 18                http://www.michaelpage.com.hk
# 19                       https://www.axa.com.hk
# 20                                          NaN
# 21                http://www.persolkelly.com.hk
# 22                                          NaN
# 23                       https://www.vyond.com/
# 24                     http://www.aztech.com.sg
# 25                        http://www.aat.com.hk
# 26                 http://www.peoplebank.com.hk
# 27                     http://www.centurysc.com
# 28                       http://www.conpak.com/
# 29                         http://www.ncs-i.com
